# %%
from get_stock_price import get_earning_history

# %%
data = get_earning_history('fb')

# %%
data
# Out:
#                period  estimate  reported  surprise  surprise_per  \
# 2016-01-27 2015-12-01      0.68      0.79      0.11         16.18
# 2015-01-28 2014-12-01      0.49      0.54      0.05         10.20
# 2014-01-29 2013-12-01      0.27      0.31      0.04         14.81
# 2013-01-30 2012-12-01      0.15      0.17      0.02         13.33
# 2018-01-31 2017-12-01      1.96      2.20      0.24         12.24
# 2012-10-23 2012-09-01      0.11      0.12      0.01          9.09
# 2014-10-28 2014-09-01      0.40      0.43      0.03          7.50
# 2013-10-30 2013-09-01      0.18      0.25      0.07         38.89
# 2017-11-01 2017-09-01      1.29      1.59      0.30         23.26
# 2016-11-02 2016-09-01      0.97      1.09      0.12         12.37
# 2015-11-04 2015-09-01      0.52      0.57      0.05          9.62
# 2017-02-01 2016-12-01      1.34      1.41      0.07          5.22
# 2015-04-22 2015-03-01      0.40      0.42      0.02          5.00
# ...

# %%
from get_plot import make_earning_plot

plot = make_earning_plot(data)

# %%
from bokeh.plotting import output_notebook, show
output_notebook()
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9e962807-5558-4d7a-87e9-32ef428f3844">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="bf51f15b-cbd9-4257-8807-e8ef1c47e63e"></div>
# </div>

# %%
source.__dict__
# Out:
# {'_id': 'f7733dd9-5268-4334-9a89-36159f25ef53',
#  '_document': <bokeh.document.document.Document at 0x1113940f0>,
#  '_event_callbacks': {},
#  '_callbacks': {},
#  '_property_values': {'data': {'period': array(['2016-09-01T00:00:00.000000000', '2017-09-01T00:00:00.000000000',
#           '2016-12-01T00:00:00.000000000', '2017-12-01T00:00:00.000000000',
#           '2015-12-01T00:00:00.000000000', '2018-03-01T00:00:00.000000000',
#           '2017-03-01T00:00:00.000000000', '2016-03-01T00:00:00.000000000',
#           '2017-06-01T00:00:00.000000000', '2016-06-01T00:00:00.000000000'],
#          dtype='datetime64[ns]'),
#    'estimate': array([-0.11,  0.06, -0.09,  0.07, -0.14,  0.05, -0.08, -0.13, -0.04,
#           -0.11]),
#    'reported': array([-0.09,  0.07, -0.04,  0.08, -0.34,  0.06,  0.05, -0.14, -0.04,
#           -0.08]),
#    'surprise': array([ 0.02,  0.01,  0.05,  0.01, -0.2 ,  0.01,  0.13, -0.01,  0.  ,
#            0.03]),
# ...
