# %%
from get_stock_price import get_daily_price, get_dividend_info, get_earning_history

# %%
price = get_daily_price("irm")
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'irm', '3. Last Refreshed': '2018-05-25', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2018-05-25': {'1. open': '33.0400', '2. high': '33.2376', '3. low': '32.9000', '4. close': '32.9900', '5. volume': '929398'}, '2018-05-24': {'1. open': '32.8400', '2. high': '33.0400', '3. low': '32.7800', '4. close': '32.9800', '5. volume': '1014555'}, '2018-05-23': {'1. open': '32.5300', '2. high': '32.8991', '3. low': '32.4700', '4. close': '32.8700', '5. volume': '903240'}, '2018-05-22': {'1. open': '32.6700', '2. high': '32.7000', '3. low': '32.2700', '4. close': '32.5200', '5. volume': '1260017'}, '2018-05-21': {'1. open': '32.2100', '2. high': '32.7550', '3. low': '32.0500', '4. close': '32.6800', '5. volume': '1355111'}, '2018-05-18': {'1. open': '32.1200', '2. high': '32.2100', '3. low': '31.8700', '4. close': '32.0800', '5. volume': '1014176'}, '2018-0
# ...

# %%
price
# Out:
#              open     high      low  close   volume   ohlc_avg    hlc_avg
# 2018-01-03  37.59  37.6900  37.0100  37.10  1866455  37.347500  37.266667
# 2018-01-04  37.13  37.2800  36.8900  36.92  1823463  37.055000  37.030000
# 2018-01-05  37.00  37.1600  36.5550  36.80  1889699  36.878750  36.838333
# 2018-01-08  36.71  37.1100  36.4300  37.04  1404569  36.822500  36.860000
# 2018-01-09  37.08  37.2800  36.8200  36.83  1106789  37.002500  36.976667
# 2018-01-10  36.75  36.7800  36.2400  36.55  1335766  36.580000  36.523333
# 2018-01-11  36.50  36.6800  36.1610  36.58  1930479  36.480250  36.473667
# 2018-01-12  36.58  36.6000  36.0500  36.22  1651957  36.362500  36.290000
# 2018-01-16  36.36  37.1100  36.2000  36.23  1346001  36.475000  36.513333
# 2018-01-17  36.40  36.4000  36.0500  36.33  1874532  36.295000  36.260000
# 2018-01-18  36.20  36.2200  35.2700  35.30  2899125  35.747500  35.596667
# 2018-01-19  35.37  35.8500  35.3100  35.49  1726339  35.505000  35.550000
# ...

# %%
from get_plot import make_earning_plot

plot = make_earning_plot(earning)

# %%
from bokeh.plotting import output_notebook, show
output_notebook()
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d11bcb4a-0c05-4e87-9e59-a3db2219108a">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a4e7e1f1-2b67-4c6f-87eb-27f2cf3b4157"></div>
# </div>

# %%
source.__dict__
# Out:
# {'_id': 'f7733dd9-5268-4334-9a89-36159f25ef53',
#  '_document': <bokeh.document.document.Document at 0x1113940f0>,
#  '_event_callbacks': {},
#  '_callbacks': {},
#  '_property_values': {'data': {'period': array(['2016-09-01T00:00:00.000000000', '2017-09-01T00:00:00.000000000',
#           '2016-12-01T00:00:00.000000000', '2017-12-01T00:00:00.000000000',
#           '2015-12-01T00:00:00.000000000', '2018-03-01T00:00:00.000000000',
#           '2017-03-01T00:00:00.000000000', '2016-03-01T00:00:00.000000000',
#           '2017-06-01T00:00:00.000000000', '2016-06-01T00:00:00.000000000'],
#          dtype='datetime64[ns]'),
#    'estimate': array([-0.11,  0.06, -0.09,  0.07, -0.14,  0.05, -0.08, -0.13, -0.04,
#           -0.11]),
#    'reported': array([-0.09,  0.07, -0.04,  0.08, -0.34,  0.06,  0.05, -0.14, -0.04,
#           -0.08]),
#    'surprise': array([ 0.02,  0.01,  0.05,  0.01, -0.2 ,  0.01,  0.13, -0.01,  0.  ,
#            0.03]),
# ...
